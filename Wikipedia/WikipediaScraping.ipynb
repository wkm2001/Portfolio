# %%
from bs4 import BeautifulSoup
import requests

import pandas as pd

# %%
url = 'https://en.wikipedia.org/wiki/List_of_largest_companies_in_the_United_Kingdom'

page = requests.get(url)

soup = BeautifulSoup(page.text, 'html')

# %%
table = soup.find_all('table', class_="wikitable sortable")[2]
#print(table)

titles = table.find_all('th')
#print(world_titles)

table_titles = [title.text.strip() for title in titles]
#print(world_table_titles)

df = pd.DataFrame(columns = table_titles)

#df

# %%
column_data = table.find_all('tr')

for row in column_data[1:]:
    row_data = row.find_all('td')
    individual_row_data = [data.text.strip() for data in row_data]
    length = len(df)
    df.loc[length] = individual_row_data

df
# Out:
#    Rank Forbes 2000 rank                            Name         Headquarters  \
# 0     1               16                       Shell plc               London
# 1     2               38                            HSBC               London
# 2     3               50                              BP               London
# 3     4               82                       Rio Tinto               London
# 4     5               96            Lloyds Banking Group               London
# 5     6              101        British American Tobacco               London
# 6     7              125                        Unilever               London
# 7     8              129                 GlaxoSmithKline               London
# 8     9              155                        Barclays               London
# 9    10              181                  Anglo American               London
# 10   11              187                           Linde            Guildford
# 11   12              240                 Legal & General               London
# 12   13              247                   NatWest Group            Edinburgh
# 13   14              277                   National Grid               London
# 14   15              287                          Diageo               London
# 15   16              296       LyondellBasell Industries               London
# 16   17              306                           Tesco   Welwyn Garden City
# 17   18              351              Standard Chartered               London
# 18   19              410                     BAE Systems  London, Farnborough
# 19   20              412                        BT Group               London
# 20   21              429                 Imperial Brands              Bristol
# 21   22              435                  CNH Industrial               London
# 22   23              461                     AstraZeneca            Cambridge
# 23   24              479                        Vodafone              Newbury
# 24   25              499           London Stock Exchange               London
# 25   26              501                           Aviva               London
# 26   27              540                      Prudential               London
# 27   28              557            Willis Towers Watson               London
# 28   29              583                  Liberty Global               London
# 29   30              584                             SSE                Perth
# 30   31              635  Coca-Cola Europacific Partners               London
# 31   32              675                            RELX               London
# 32   33              686                        Ferguson            Wokingham
# 33   34              725               Reckitt Benckiser               Slough
# 34   35              756                             WPP               London
# 35   36              820                   Phoenix Group               London
# 36   37              826                St James's Place          Cirencester
# 37   38              827                           Segro               London
# 38   39              848                   Compass Group             Chertsey
# 39   40              915        Associated British Foods               London
# 40   41              921                             M&G               London
# 41   42              942                           Amcor              Warmley
# 42   43              990                        Centrica              Windsor
# 43   44             1040                   Ashtead Group               London
# 44   45             1045                 Antofagasta plc               London
# 45   46             1057                        3i Group               London
# 46   47             1136                     Sainsbury's               London
# 47   48             1147                           Evraz               London
# 48   49             1150                     Rolls-Royce               London
# 49   50             1160                  Kingfisher plc               London
#
#    Revenue(billions US$) Profit(billions US$) Assets(billions US$)  \
# 0                 261.76                20.27               404.38
# 1                  59.33                12.58             2,957.94
# 2                 158.01                 7.55               287.27
# 3                  63.46                21.06               102.90
# 4                  58.48                 7.36             1,200.75
# 5                  35.32                 9.34               186.05
# 6                  62.00                 7.15                85.40
# 7                  46.92                 6.03               107.14
# 8                  30.17                 8.77             1,874.94
# 9                  41.52                 8.54                65.98
# 10                 30.79                 3.83                81.61
# 11                 62.51                 2.79               779.43
# 12                 17.86                 4.41             1,059.17
# 13                 20.77                 2.07               119.92
# 14                 19.00                 4.19                44.91
# 15                 46.15                  5.6                36.74
# 16                 84.17                 2.06                66.22
# 17                 18.88                 1.96               827.82
# 18                 26.85                 2.42                36.75
# 19                 28.84                 1.43                69.55
# 20                 22.66                 3.88                39.22
# 21                 33.43                 1.72                49.42
# 22                 38.68                 0.09               105.36
# 23                 53.63                −0.29               178.59
# 24                  9.27                 0.83              1,066.1
# 25                 45.13                 0.57               465.18
# 26                 26.52                −1.98               189.35
# 27                  9.58                 4.22                34.97
# 28                 10.54                13.43                46.92
# 29                 10.33                 3.52                31.56
# 30                 16.24                 1.15                33.08
# 31                  9.95                 2.02                18.77
# 32                 22.74                 1.86                 14.1
# 33                  18.2                −0.04                 36.5
# 34                 17.61                 0.87                38.05
# 35                 33.53                −1.18               440.48
# 36                 24.42                 0.39               210.82
# 37                  0.75                 5.58                24.09
# 38                  24.5                 0.48                20.05
# 39                 18.99                 0.65                22.78
# 40                 23.38                 0.11               294.55
# 41                 13.59                 0.94                17.14
# 42                 20.28                 0.80                36.69
# 43                  7.65                 1.18                14.78
# 44                  7.47                 1.29                17.28
# 45                  0.33                 3.83                16.62
# 46                 40.82                 0.38                34.62
# 47                 13.49                 3.04                 9.85
# 48                 15.43                 0.21                38.84
# 49                 18.12                 1.16                16.57
#
#    Value(billions US$)                Industry
# 0                211.1             Oil and Gas
# 1                135.3                 Banking
# 2                98.38             Oil and Gas
# 3               117.78                  Mining
# 4                31.34                 Banking
# 5                97.49          Consumer goods
# 6               116.16          Consumer goods
# 7               112.09         Pharmaceuticals
# 8                31.55                 Banking
# 9                59.44                  Mining
# 10              157.26               Chemicals
# 11               19.63               Insurance
# 12               30.22                 Banking
# 13               54.88               Utilities
# 14              116.05               Beverages
# 15               34.94               Chemicals
# 16               25.89                  Retail
# 17               19.69                 Finance
# 18               30.15   Aerospace and defence
# 19               23.74       Telecommunication
# 20               20.62          Consumer goods
# 21               20.19             Industrials
# 22              204.56         Pharmaceuticals
# 23               46.36       Telecommunication
# 24               52.66                 Finance
# 25               21.03               Insurance
# 26                36.7               Insurance
# 27               26.88               Insurance
# 28               12.59       Telecommunication
# 29               24.88                  Energy
# 30               23.43               Beverages
# 31               59.18                Services
# 32               29.61  Construction materials
# 33               56.35          Consumer goods
# 34               14.80             Advertising
# 35                7.93               Insurance
# 36                9.31               Insurance
# 37               21.23             Real estate
# 38               39.01                Services
# 39               16.58                  Retail
# 40                6.99               Insurance
# 41               17.53     Packaging materials
# 42                5.96               Utilities
# 43               26.45                Services
# 44               18.92                  Mining
# 45               16.82                 Finance
# 46                 717                  Retail
# 47                1.52                  Mining
# 48                9.84   Aerospace and defence
# 49                6.77                  Retail

# %%
path = r'C:\Users\matte\Desktop\Portfolio\WikipediaScrapingTable.csv'
df.to_csv(path, index = False)
